# %%
import pandas as pd

# %%
path = 'de_para_ordem_de_servico.xlsx'

# %%
de_para = pd.read_excel(path)

# %%
de_para
# Out:
#          Empresa                                 Ord Serviço
# 0       VEMFLORS           2023_10_luizfernando_vemflors_ref
# 1       VEMFLORS           2023_10_luizfernando_vemflors_ref
# 2       VEMFLORS           2023_10_luizfernando_vemflors_ref
# 3       VEMFLORS           2023_10_luizfernando_vemflors_ref
# 4       VEMFLORS           2023_10_luizfernando_vemflors_ref
# ...          ...                                         ...
# 125179   EMFLORS  2023_12_philippesouzaoliveira_emflors_prog
# 125180   EMFLORS  2023_12_philippesouzaoliveira_emflors_prog
# 125181   EMFLORS  2023_12_philippesouzaoliveira_emflors_prog
# 125182   EMFLORS  2023_12_philippesouzaoliveira_emflors_prog
# 125183   EMFLORS  2023_12_philippesouzaoliveira_emflors_prog
#
# [125184 rows x 2 columns]

# %%
de_para['nome'] = de_para['Ord Serviço'].str.split("_", n=2).str[2]

# %%
de_para
# Out:
#          Empresa                                 Ord Serviço  \
# 0       VEMFLORS           2023_10_luizfernando_vemflors_ref
# 1       VEMFLORS           2023_10_luizfernando_vemflors_ref
# 2       VEMFLORS           2023_10_luizfernando_vemflors_ref
# 3       VEMFLORS           2023_10_luizfernando_vemflors_ref
# 4       VEMFLORS           2023_10_luizfernando_vemflors_ref
# ...          ...                                         ...
# 125179   EMFLORS  2023_12_philippesouzaoliveira_emflors_prog
# 125180   EMFLORS  2023_12_philippesouzaoliveira_emflors_prog
# 125181   EMFLORS  2023_12_philippesouzaoliveira_emflors_prog
# 125182   EMFLORS  2023_12_philippesouzaoliveira_emflors_prog
# 125183   EMFLORS  2023_12_philippesouzaoliveira_emflors_prog
#
#                                       nome
# 0                luizfernando_vemflors_ref
# 1                luizfernando_vemflors_ref
# 2                luizfernando_vemflors_ref
# 3                luizfernando_vemflors_ref
# ...

# %%
de_para.to_excel(path)
